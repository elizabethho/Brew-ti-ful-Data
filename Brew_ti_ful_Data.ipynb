# %% [markdown]
# <a href="https://colab.research.google.com/github/elizabethho/Brew-ti-ful-Data/blob/main/Brew_ti_ful_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Brew-ti-ful Data: Analyzing the characteristics of high quality coffee
# ## Elizabeth Ho, Hanna Mitschke, and Sam Stone

# %% [markdown]
# Overview and Mo2va2on: Provide an overview of the project goals and the moKvaKon
# for it. Consider that this will be read by people who did not see your project proposal.<br>
# Related Work: Anything that inspired you, such as a paper, a web site, or something we
# discussed in class. <br>
# Ini2al Ques2ons: What quesKons are you trying to answer? How did these quesKons
# evolve over the course of the project? What new quesKons did you consider in the
# course of your analysis?<br>
# Data: Source, scraping method, cleanup, storage, etc.<br>
# Exploratory Data Analysis and Models: What visualizaKons did you use to look at your
# data in different ways? What are the different staKsKcal methods you considered?
# JusKfy the decisions you made, and show any major changes to your ideas. How did you
# reach these conclusions?<br>
# Final Analysis: What did you learn about the data? How did you answer the quesKons?
# How can you jusKfy your answers?<br>
# Presenta2on: Present your final results in a compelling and engaging way using text,
# visualizaKons, and images.

# %% [markdown]
# ## not really possible but do agree that not everyone may understand quality scores
# My team and I really enjoyed your topic as we all are coffee lovers. One major feedback we have is if possible we think you should somehow include cost as a variable in this analysis. We think either or both the production cost or the retail price would have an impact on the coffee as well. It would be interesting to see how to the quality or the production cost has an impact on the retail price. We think that money would be a better indicator because not everyone would understand quality scores.
#
# ## possible, but other data has a lot fewer. honestly worth a shot
# One thing that may be interesting to see is to analyze if the trend shown in the coffee of choice (in this case, the Arabica coffee plant) is reflected in other types of coffee, too. With data across multiple types of coffee plants, it would be interesting to see if any patterns show up like if a certain region seems to produce consistently higher scoring coffee or something similar. Additionally, looking at multiple types of coffee plants may make your analysis more generalized for all types of coffee instead of just the Arabica coffee plant, focusing more on what makes higher scoring coffee rather than just higher scoring Arabica coffee.
#
# ## yes to using cleaned dataset, last 2 bullets are good too
# - I'm a *BIG* coffee drinker (Cav), so I have very high hopes for this project.
# - Data looks good, and there are a lot of things you can explore with this dataset
# - The cleaned data has been provided in that Github repo. You may investigate the raw data and cleaned data first to determine if any further cleaning is needed.
# - In this dataset, the coffee's quality is measured in 11 different dimensions. You may want to take this into consideration when planning for clustering and classification since you are not dealing with a single target.
# - And for clustering, you may need to spend some time making sense of what you discover. Are there clusters corresponding to "super strong", "chocolatey", etc.? You will want to see if you can find interesting themes (which may require you to assign your own naming conventions).
#
# ## maybe allow users to interact with it, subjectivity, coffees with similar attributes
# Firstly, really good idea for a project overall, interesting and is with a pretty large group of people who would be interested. One question that I have is, is there going to be any way to remove preferences when looking at the quality score, or is the quality score just a value given by some sort of experts in the field? And this might be a bit of a stretch, but one interesting thing y'all might think about doing is some sort of similarity matrix that will let you select a coffee that you already know you enjoy, and find the cluster of coffees with similar attributes. Again though, I think y'all have a really good starting point to branch out from whatever direction y'all go with it!
#
# https://www.scaa.org/PDF/resources/cupping-protocols.pdf
# https://github.com/jldbc/coffee-quality-database

# %%
# imports

import re
import pandas as pd
from sklearn import cluster
# from sklearn.cluster import KMeans
import seaborn as sns

# %%
arabica_cleaned = pd.read_csv('https://raw.githubusercontent.com/elizabethho/Brew-ti-ful-Data/main/arabica_data_cleaned.csv')
arabica_raw = pd.read_csv('https://raw.githubusercontent.com/elizabethho/Brew-ti-ful-Data/main/arabica_ratings_raw.csv')
robusta_cleaned = pd.read_csv('https://raw.githubusercontent.com/elizabethho/Brew-ti-ful-Data/main/robusta_data_cleaned.csv')
robusta_raw = pd.read_csv('https://raw.githubusercontent.com/elizabethho/Brew-ti-ful-Data/main/robusta_ratings_raw.csv')

# %%
arabica_cleaned.drop(['Lot.Number', 'ICO.Number', 'Certification.Address','Certification.Contact','Altitude','unit_of_measurement'], axis=1)
arabica_cleaned.drop(arabica_cleaned[arabica_cleaned['Total.Cup.Points'] == 0].index, inplace = True)
arabica_cleaned['continent'] = arabica_cleaned['Country.of.Origin'].map({'Costa Rica':'Central America', 'El Salvador':'Central America',
  'Guatemala':'Central America','Honduras':'Central America','Nicaragua':'Central America',
  'Mexico':'North America','United States':'North America','United States (Hawaii)':'North America',
  'Haiti':'North America','United States (Puerto Rico)':'North America',
  'Brazil':'South America','Columbia':'South America','Panama':'South America',
  'Peru':'South America','Ecuador':'South America',
  'China':'Asia','Taiwan':'Asia','Japan':'Asia','India':'Asia','Indonesia':'Asia','Laos':'Asia',
  'Myanmar':'Asia','Philippines':'Asia','Thailand':'Asia','Vietnam':'Asia','Papua New Guinea':'Asia',
  'Côte d\'Ivoire':'Africa','Ethiopia':'Africa','Kenya':'Africa','Malawi':'Africa','Mauritius':'Africa',
  'Rwanda':'Africa','Uganda':'Africa','United Republic of Tanzania':'Africa','Zambia':'Africa'})
arabica_cleaned.head()
# Out:
#    Unnamed: 0  Species  ... altitude_mean_meters        continent
# 0           1  Arabica  ...               2075.0           Africa
# 1           2  Arabica  ...               2075.0           Africa
# 2           3  Arabica  ...               1700.0  Central America
# 3           4  Arabica  ...               2000.0           Africa
# 4           5  Arabica  ...               2075.0           Africa
#
# [5 rows x 45 columns]

# %%
subset = arabica_cleaned[["Aroma", "Flavor", "Aftertaste", "Acidity", "Body", "Balance", "Uniformity", "Clean.Cup", "Sweetness", "Cupper.Points", "Total.Cup.Points"]]
# x_vars = ["body_mass_g", "bill_length_mm", "bill_depth_mm", "flipper_length_mm"]
# y_vars = ["body_mass_g"]
# g = sns.PairGrid(subset) #  hue="Country.of.Origin",
g = sns.PairGrid(arabica_cleaned, hue="continent", x_vars=subset, y_vars=subset)
g.map(sns.scatterplot)

# %% [markdown]
# ##cleaning
#
# cleaning they did:
# * convert ft to meters for altitude
# * made altitude range seperate columns
# * got rid of "NA" columns
#
# columns we got rid of:
# * lot number
# * ICO numner
# * certification address
# * cetification contact
# * altitude
# * unit of measurement
#
# other cleaning:
# * get rid of row that has all 0s

# %% [markdown]
# Central America
# Costa Rica
# El Salvador
# Guatemala
# Honduras
# Nicaragua
#
# North America
# Mexico
# US
# Hawaii
# Haiti
# Puerto Rico
#
# South America
# Brazil
# Columbia
# Panama
# Peru
# Ecuador
#
# Asia
# China
# Taiwan
# Japan
# India
# Indonesia
# Laos
# Myanmar
# Philippines
# Thailand
# Vietnam
# Papua New Guinea
#
# Africa
# Côte d'Ivoire
# Ethiopia
# Kenya
# Malawi
# Mauritius
# Rwanda
# Uganda
# United Republic of Tanzania
# Zambia
